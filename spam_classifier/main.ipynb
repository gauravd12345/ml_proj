# %%
import pandas
from sklearn.model_selection import train_test_split

df = pandas.read_csv("spam.csv", encoding="latin1") # spam dataset is saved as latin1 encoding, not utf-8
v1, v2 = df.columns[:2]

X_train, X_test, y_train, y_test = train_test_split(df[v2], df[v1], test_size=0.2)

# %% [markdown]
# ### Approach #1: BoW(Bag of Words) Count Vectorizer + BernoulliNB Classifier

# %%
"""
In this approach, we categorize words using the BoW model and Bernoulli NB. 

The steps are:
    1. Using scikit-learn's CountVectorizer() we build a frequency count of all words. 
    2. We feed this information into the Bernoulli Naive Bayes classifier to train our model. 
       Naive Bayes is a statistical algorithm that uses probability counts to predict whether 
       a given word belongs to certain class(spam vs. not spam). It uses Bayes theorem to do so.

"""

from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import BernoulliNB
from sklearn.feature_extraction.text import CountVectorizer

pipe = Pipeline([
    ("vectorizer", CountVectorizer()),
    ("classifier", BernoulliNB())
])

pipe.fit(X_train, y_train)
score = pipe.score(X_test, y_test)
# print("Accuracy:", score)
